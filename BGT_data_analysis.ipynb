# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
import pickle
with open("co2_emmissions.pkl","rb") as f:
     a=pickle.load(f)

# %%
a.head()
# Out:
#   Country Name Country Code                          Indicator Name  \
# 0        Aruba          ABW  CO2 emissions (metric tons per capita)
# 1  Afghanistan          AFG  CO2 emissions (metric tons per capita)
# 2       Angola          AGO  CO2 emissions (metric tons per capita)
# 3      Albania          ALB  CO2 emissions (metric tons per capita)
# 4      Andorra          AND  CO2 emissions (metric tons per capita)
#
#    Indicator Code      1960      1961      1962      1963      1964      1965  \
# 0  EN.ATM.CO2E.PC       NaN       NaN       NaN       NaN       NaN       NaN
# 1  EN.ATM.CO2E.PC  0.046057  0.053589  0.073721  0.074161  0.086174  0.101285
# 2  EN.ATM.CO2E.PC  0.100835  0.082204  0.210531  0.202737  0.213560  0.205891
# 3  EN.ATM.CO2E.PC  1.258195  1.374186  1.439956  1.181681  1.111742  1.166099
# 4  EN.ATM.CO2E.PC       NaN       NaN       NaN       NaN       NaN       NaN
#
#    ...       2006       2007       2008       2009       2010       2011  \
# ...

# %%
a.shape
# Out:
# (264, 60)

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 60 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    264 non-null    object
#  1   Country Code    264 non-null    object
#  2   Indicator Name  264 non-null    object
#  3   Indicator Code  264 non-null    object
#  4   1960            193 non-null    float64
#  5   1961            194 non-null    float64
#  6   1962            196 non-null    float64
#  7   1963            197 non-null    float64
#  8   1964            203 non-null    float64
#  9   1965            203 non-null    float64
#  10  1966            203 non-null    float64
#  11  1967            203 non-null    float64
#  12  1968            203 non-null    float64
#  13  1969            203 non-null    float64
#  14  1970            205 non-null    float64
#  15  1971            206 non-null    float64
#  16  1972            208 non-null    float64
# ...

# %%
df = a[a['1960'].notna()]

# %%
df
# Out:
#              Country Name Country Code  \
# 1             Afghanistan          AFG
# 2                  Angola          AGO
# 3                 Albania          ALB
# 5              Arab World          ARB
# 6    United Arab Emirates          ARE
# ..                    ...          ...
# 255               Vietnam          VNM
# 257                 World          WLD
# 258                 Samoa          WSM
# 260           Yemen, Rep.          YEM
# 261          South Africa          ZAF
#
#                              Indicator Name  Indicator Code      1960  \
# 1    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  0.046057
# 2    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  0.100835
# 3    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  1.258195
# 5    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  0.645736
# 6    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  0.119035
# ...

# %%
a=pd.read_csv("data.csv",sep=",")

# %%
a
# Out:
#         COU       Country  POL         Pollutant         VAR  \
# 0       AUS     Australia  GHG  Greenhouse gases       TOTAL
# 1       AUS     Australia  GHG  Greenhouse gases       TOTAL
# 2       AUS     Australia  GHG  Greenhouse gases       TOTAL
# 3       AUS     Australia  GHG  Greenhouse gases       TOTAL
# 4       AUS     Australia  GHG  Greenhouse gases       TOTAL
# ...     ...           ...  ...               ...         ...
# 51609  OECD  OECD - Total  GHG  Greenhouse gases  ENER_CO2_P
# 51610  OECD  OECD - Total  GHG  Greenhouse gases  ENER_CO2_P
# 51611  OECD  OECD - Total  GHG  Greenhouse gases  ENER_CO2_P
# 51612  OECD  OECD - Total  GHG  Greenhouse gases  ENER_CO2_P
# 51613  OECD  OECD - Total  GHG  Greenhouse gases  ENER_CO2_P
#
#                                   Variable   YEA  Year   Unit Code  \
# 0        Total  emissions excluding LULUCF  1990  1990  T_CO2_EQVT
# 1        Total  emissions excluding LULUCF  1991  1991  T_CO2_EQVT
# ...

# %%
pol="CO2"
a[(a["Country"]=="India")& (a["Year"]==2000) & (a["VAR"]=="TOTAL") & (a["POL"]==pol)]["Value"]
# Out:
# 21819    1024772.9
# Name: Value, dtype: float64

# %%
a[(a["Country"]=="United States")& (a["Year"]==2000) & (a["VAR"]=="TOTAL") & (a["POL"]==pol)]["Value"].sum()
# Out:
# 5997298.9120000005

# %%
countries=list(set(a["Country"]))

# %%
years=list(set(a["Year"]))

# %%
c02_consumption=[]
country=[]
year=[]
for x in countries:
    for y in years:
        b=a[(a["Country"]==x)& (a["Year"]==y) & (a["VAR"]=="TOTAL") & (a["POL"]==pol)]["Value"]
        c02_consumption.append(b.sum())
        country.append(x)
        year.append(y)

# %%
df=pd.DataFrame()

# %%
df["Co2_consumption"]=c02_consumption

# %%
df["year"]=year
df["country"]=country

# %%
df.head()
# Out:
#    Co2_consumption  year    country
# 0       100932.724  1990  Argentina
# 1       109765.393  1991  Argentina
# 2       112308.399  1992  Argentina
# 3       114520.671  1993  Argentina
# 4       120321.610  1994  Argentina

# %%
#Compute per year maximum
import numpy as np
max_in_years=[]
for x in years:
    y=np.max(df[df["year"]==x]["Co2_consumption"])
    max_in_years.append(y)

# %%
max_in_years
# Out:
# [5121179.44,
#  5071563.914,
#  5174670.601,
#  5281386.608,
#  5375033.802999999,
#  5436697.9860000005,
#  5625041.885,
#  5701920.919,
#  5749893.056,
#  5829519.951,
#  5997298.9120000005,
#  5899855.485,
#  5942421.41,
#  5991190.935,
#  6105444.11,
#  6130552.417,
#  6050384.603999999,
#  6127888.221,
#  5928256.329,
#  5493547.908,
#  5700108.337,
#  5572584.775,
#  9893257.0,
#  5522908.365,
#  5572106.312000001,
#  5422965.677,
#  5306662.4569999995,
#  5270748.525]

# %%
years
# Out:
# [1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017]

# %%
import matplotlib.pyplot as plt
plt.plot(years,max_in_years)
plt.xlabel('years')
plt.ylabel('Max per country CO2 emissions')
# Out:
# Text(0, 0.5, 'Max per country CO2 emissions')

# %%
#Compute per year maximum
import numpy as np
mean_in_years=[]
for x in years:
    y=np.mean(df[df["year"]==x]["Co2_consumption"])
    mean_in_years.append(y)

# %%
import matplotlib.pyplot as plt
plt.plot(years,mean_in_years)
plt.xlabel('years')
plt.ylabel('Mean CO2 emissions')
# Out:
# Text(0, 0.5, 'Mean CO2 emissions')

# %%
# Per country eg: developing country India
ch=df[df["country"]=="Switzerland"]
plt.plot(ch["year"],ch["Co2_consumption"])
plt.xlabel('years')
plt.ylabel('Switzerland Co2 emissions')
# Out:
# Text(0, 0.5, 'Switzerland Co2 emissions')

# %%
us=df[df["country"]=="United Kingdom"]
plt.plot(us["year"],us["Co2_consumption"])
plt.xlabel('years')
plt.ylabel('United Kingdom Co2 emissions')
# Out:
# Text(0, 0.5, 'United Kingdom Co2 emissions')

# %%
us=df[df["country"]=="United States"]
plt.plot(us["year"],us["Co2_consumption"])
plt.xlabel('years')
plt.ylabel('United States Co2 emissions')
# Out:
# Text(0, 0.5, 'United States Co2 emissions')

# %%
countries
# Out:
# ['Argentina',
#  'Turkey',
#  'OECD - Total',
#  'Colombia',
#  'South Africa',
#  'Germany',
#  'Austria',
#  'OECD - Europe',
#  'Ireland',
#  'United Kingdom',
#  'Netherlands',
#  'India',
#  'Greece',
#  'Sweden',
#  'Korea',
#  'Norway',
#  'New Zealand',
#  'France',
#  'Belgium',
#  'Brazil',
#  'Iceland',
#  'Israel',
#  'Chile',
#  'Costa Rica',
#  'European Union (28 countries)',
#  'Slovenia',
#  'Latvia',
#  'Indonesia',
#  'Luxembourg',
#  'Poland',
#  'Canada',
#  'Lithuania',
#  "China (People's Republic of)",
#  'Russia',
#  'Hungary',
#  'Spain',
#  'Australia',
#  'United States',
#  'Portugal',
#  'Czech Republic',
#  'Japan',
#  'Slovak Republic',
#  'Mexico',
#  'Switzerland',
#  'Denmark',
#  'Finland',
#  'Estonia',
#  'Italy']

# %%
chile=df[df["country"]=="Indonesia"]
plt.plot(chile["year"][:-1],chile["Co2_consumption"][:-1])

# %%
lt=df[df["country"]=="Colombia"]
plt.plot(lt["year"][:-3],lt["Co2_consumption"][:-3])
plt.xlabel('years')
plt.ylabel('Colombia Co2 emissions')
# Out:
# Text(0, 0.5, 'Colombia Co2 emissions')

# %%
lt=df[df["country"]=="Argentina"]
plt.plot(lt["year"][:-3],lt["Co2_consumption"][:-3])
plt.xlabel('years')
plt.ylabel('Argentina Co2 emissions')
# Out:
# Text(0, 0.5, 'Argentina Co2 emissions')

# %%
means=[]
c=[]
for x in countries:
    if np.mean(df[(df["country"]==x)]["Co2_consumption"])!=0.0:
       means.append(np.mean(df[(df["country"]==x)]["Co2_consumption"]))
       c.append(x)

# %%
plt.hist(means)
plt.xlabel('Mean Co2 emmisions per country')
plt.ylabel('Number of countries')
# Out:
# Text(0, 0.5, 'Number of countries')

# %%
top5=np.array(means).argsort()[-10:][::-1]
for x in top5:
    print(c[x])
# Out:
# United States
# European Union (28 countries)
# Russia
# Japan
# Germany
# China (People's Republic of)
# Canada
# United Kingdom
# Korea
# Italy

# %%
top5=np.array(means).argsort()[0:10][::-1]
for x in top5:
    print(c[x])
# Out:
# Indonesia
# New Zealand
# South Africa
# Estonia
# Lithuania
# Slovenia
# Luxembourg
# Latvia
# Iceland
# Costa Rica

# %%
year
# Out:
# [1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
# ...

# %%
len(set(year))
# Out:
# 28
